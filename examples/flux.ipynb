# %%
pip install ipykernel ipywidgets

# %%
from smolagents import Tool
from PIL import Image

image_generation_tool = Tool.from_space(
    "black-forest-labs/FLUX.1-schnell",
    name="image_generator",
    description="Generate an image from a prompt"
)

# The tool expects a parameter named 'prompt'
img_path = image_generation_tool(prompt="Rising sun at the beach")

# Open the image
img = Image.open(img_path)

# Display the image
display(img)
# Out:
# Since `api_name` was not defined, it was automatically set to the first avilable API: `/infer`.
# Loaded as API: https://black-forest-labs-flux-1-schnell.hf.space ✔
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>
